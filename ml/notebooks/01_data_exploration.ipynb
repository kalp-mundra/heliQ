# %%
import pandas as pd

base_path = "../../dataset"

files = {
    "Plant 1 Generation": f"{base_path}/energy_prediction/Plant_1_Generation_Data.csv",
    "Plant 1 Weather": f"{base_path}/energy_prediction/Plant_1_Weather_Sensor_Data.csv",
    "Plant 2 Generation": f"{base_path}/energy_prediction/Plant_2_Generation_Data.csv",
    "Plant 2 Weather": f"{base_path}/energy_prediction/Plant_2_Weather_Sensor_Data.csv",
    "Fault Train": f"{base_path}/fault_detection/train_data.csv",
    "Fault Test": f"{base_path}/fault_detection/test_data.csv"
}

data = {}

for name, path in files.items():
    data[name] = pd.read_csv(path)
    print(f"{name}: {data[name].shape}")
